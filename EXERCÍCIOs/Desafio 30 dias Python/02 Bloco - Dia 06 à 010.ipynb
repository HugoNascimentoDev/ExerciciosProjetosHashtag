# %% [markdown]
# Dia 6 – Média como critério
# Enunciado:
# Crie uma lista apenas com valores acima da média.
# O que deve ser feito:
# - Resolver o problema proposto
# - Utilizar os conceitos estudados
# - Garantir clareza e organização
# Base de dados:
# [500, 1200, 800, 2000, 1500, 700]

# %%
vendas = [500, 1200, 800, 2000, 1500, 700]

def verificando_vendas (lista):
    acima_da_media = []
    total_vendas = sum(lista)
    qtd_vendas = len(lista)
    media = total_vendas / qtd_vendas
    qtd_acima_media = 0
    
    for venda in lista:
        if venda > media:
            acima_da_media.append(venda)
            qtd_acima_media += 1
    perc_acima_media = (qtd_acima_media / qtd_vendas)

    return acima_da_media, media, perc_acima_media, qtd_acima_media, total_vendas, qtd_vendas

acima_da_media, media, perc_acima_media, qtd_acima_media, total_vendas, qtd_vendas = (verificando_vendas(vendas))

print(f'''Valor total de vendas: {total_vendas}
Quantidade total de vendas: {qtd_vendas}
Média de vendas: {media:.2f}
Quantidade de vendas acima da média: {qtd_acima_media}
Percentual acima da média: {perc_acima_media:.2%}''')
for venda in acima_da_media:
    print(f'Valor da Venda acima da média: {venda}')
# Out:
# Valor total de vendas: 6700
# Quantidade total de vendas: 6
# Média de vendas: 1116.67
# Quantidade de vendas acima da média: 3
# Percentual acima da média: 50.00%
# Valor da Venda acima da média: 1200
# Valor da Venda acima da média: 2000
# Valor da Venda acima da média: 1500

# %% [markdown]
# Dia 7 – Ranking simples
# Enunciado:
# Gere um ranking de vendedores do maior para o menor faturamento.
# O que deve ser feito:
# - Resolver o problema proposto
# - Utilizar os conceitos estudados
# - Garantir clareza e organização
# Base de dados:
# {'Ana': 35000, 'Bruno': 42000, 'Carlos': 28000, 'Daniela': 51000}

# %%
vendas = {'Ana': 35000, 'Bruno': 42000, 'Carlos': 28000, 'Daniela': 51000}

def ordenador_vendas (dicionario):
    ordenado_menor_para_maior_dict = dict(sorted(dicionario.items(), key = lambda item: item[1]))
    ordenado_maior_para_menor_dict = dict(sorted(dicionario.items(), key = lambda item: item[1], reverse= True))

    return ordenado_menor_para_maior_dict, ordenado_maior_para_menor_dict

ordenado_menor_para_maior_dict, ordenado_maior_para_menor_dict = (ordenador_vendas(vendas))

print('=' * 50)
print('RANKING VENDAS (MENOR PARA O MAIOR)')
print('=' * 50)
contador = 0
for vendedor, t_vendas in ordenado_menor_para_maior_dict.items():
    contador += 1 
    print(f'{contador}º - {vendedor.upper()}: {t_vendas}')

print('=' * 50)
print('RANKING VENDAS (MAIOR PARA O MENOR)')
print('=' * 50)
contador = 0
for vendedores, to_vendas in ordenado_maior_para_menor_dict.items():
    contador += 1
    print(f'{contador}º - {vendedores.upper()}: {to_vendas}')

print('=' * 50)
# Out:
# ...
# RANKING VENDAS (MENOR PARA O MAIOR)
# ...
# 1º - CARLOS: 28000
# 2º - ANA: 35000
# 3º - BRUNO: 42000
# 4º - DANIELA: 51000
# ...
# RANKING VENDAS (MAIOR PARA O MENOR)
# ...
# 1º - DANIELA: 51000
# 2º - BRUNO: 42000
# 3º - ANA: 35000
# 4º - CARLOS: 28000
# ...

# %% [markdown]
# Dia 8 – Função com múltiplos retornos
# Enunciado:
# Crie uma função que retorne total, média e maior valor.
# O que deve ser feito:
# - Resolver o problema proposto
# - Utilizar os conceitos estudados
# - Garantir clareza e organização
# Base de dados:
# [1200, 850, 430, 2100, 980]

# %%
lista = [1200, 850, 430, 2100, 980]

def verificador_de_lista (lista):
    maior_valor = max(lista)
    menor_valor = min(lista)
    valor_total = sum(lista)
    media = valor_total / len(lista)
    return maior_valor, menor_valor, valor_total, media

maior_valor, menor_valor, valor_total, media = verificador_de_lista(lista)

def resumo (maior_valor, menor_valor, valor_total ,  media):
    print('=' * 32)
    print('RESUMO VALOR'.center(32))
    print('=' * 32)
    print(f'''MAIOR valor: \t\t{maior_valor}
MENOR valor: \t\t{menor_valor}
Valor total: \t\t{valor_total}
Média: \t\t\t{media:.2f}''')
    print('-' * 32)

resumo(maior_valor, menor_valor, valor_total, media)
# Out:
# ...
#           RESUMO VALOR
# ...
# MAIOR valor: 		2100
# MENOR valor: 		430
# Valor total: 		5560
# Média: 			1112.00
# --------------------------------

# %% [markdown]
# Dia 7 – Ranking simples
# Enunciado:
# Gere um ranking de vendedores do maior para o menor faturamento.
# O que deve ser feito:
# - Resolver o problema proposto
# - Utilizar os conceitos estudados
# - Garantir clareza e organização
# Base de dados:
# {'Ana': 35000, 'Bruno': 42000, 'Carlos': 28000, 'Daniela': 51000}
#
# Dia 9 – Planejamento sem código
# Enunciado:
# Planeje a solução de um exercício médio antes de codar.
# O que deve ser feito:
# - Resolver o problema proposto
# - Utilizar os conceitos estudados
# - Garantir clareza e organização
# Base de dados:
# Exercício do Dia 7

# %% [markdown]
# ## Minha resposta
#
# 1. Entendimento
#
# 1.1. Gerar um ranking de vendedores
#
# 1.2. Imprimir um ranking do maior para o menor baseado no faturamento
#
# 1.3. Colocar em ordem a partir da quantidade faturada
#
# ### Resposta da IA
# - O que é ranking? → posição ordenada baseada em critério.
# - Qual é o critério? → faturamento.
# - O que define a posição? → comparação entre valores.
# - O que acontece em caso de empate?
#
# ___
# 2. Estrutura de Dados
#
# 2.1. Temos um dicionário
#
# 2.2. Está organizando com a chave citando o nome do vendedor e o valor é quantidade de faturamento
#
# 2.3. Chave é o nome do vendedor
#
# 2.4. Valor é a quantidade total de faturamento de cada vendendor
#
# ### Resposta da IA
# - O dicionário é a melhor estrutura para ranking?
# - Depois de ordenar, ele ainda continua sendo dicionário?
# - Ranking é estático ou pode mudar?
#
# ___
# 3.Estratégia de Solução
#
# 3.1.Acessar o dicionário
#
# 3.2.Colocar as chaves e seus respectivos valores em ordem dentro do dicionário a partir do valor
#
# 3.3.Colocar em ordem do maior para o menor
#
# 3.4.Imprimir o dicionário final, criando um ranking do maior para o menor
#
# ### Resposta da IA
# - Identificar total de vendedores
# - Ordenar os dados pelo valor (critério claro)
# - Definir tipo de ordenação (decrescente)
# - Percorrer estrutura ordenada
# - Criar contador de posição
# - Exibir posição + nome + valor
# ___
# 4.Melhorias Estratégicas
# - Incluir o percentual de cada venda com relação ao total faturado de todos os vendedores
# - Criar uma média geral de faturamento em cima da quantidade total de vendedores
# - Incluir a diferença sequencial entre o primeiro ranqueado e o segundo, o segundo e o terceiro e subsequentemente a
# - Criar uma lista identificando todos os que estão acima da média geral
#
# ___
#
# 5.Riscos e Pontos de Atenção
# - Caso exista dois vendedores com o mesmo valor considerar um após o outro sem filtro adicional
# - se o dicionário estiver vazio, tratar o erro e imprimir que o texto que "Não possuímos dados suficientes para criar um ranking"
# - caso os valores sejam negativos, devem ser considerados menores que 0 e deve entrar no ranking de acordo com a sua posição
#
# ___

# %% [markdown]
# # 📘 Dia 10 – Desafio de Autonomia
#
# ## 🎯 Título:
# Análise Completa de Performance de Equipe Comercial
#
# ---
#
# ## 📊 Contexto
#
# Você recebeu os dados de faturamento trimestral de vendedores de uma empresa.
#
# Seu papel é gerar uma análise estratégica da performance da equipe.
#
# ---
#
# # 📌 Etapas do Desafio
#
# ## 1️⃣ Para cada vendedor, calcular:
#
# - Total no trimestre
# - Média mensal
# - Maior mês
# - Menor mês
#
# ---
#
# ## 2️⃣ Gerar ranking do trimestre:
#
# - Ordenar do maior total para o menor
# - Mostrar posição no ranking (1º, 2º, 3º…)
#
# ---
#
# ## 3️⃣ Calcular indicadores gerais da equipe:
#
# - Total geral da equipe
# - Média geral por vendedor
# - Identificar quem está acima da média geral
# - Percentual que cada vendedor representa no total da equipe
#
# ---
#
# ## 4️⃣ Análises estratégicas adicionais:
#
# - Diferença entre o 1º e o 2º colocado
# - Avaliar se existe concentração de faturamento no topo
# - Identificar quantos vendedores estão abaixo da média
#
# ---
#
# # 📌 Regras do Desafio
#
# - Organize a solução em funções
# - Separe cálculo de apresentação
# - Use nomes de variáveis claros
# - Evite código repetido
# - Pense antes de codar (faça um pequeno planejamento escrito)
#
# ---
#
# # 🧠 Objetivo do Dia 10
#
# Treinar:
#
# - Estruturação lógica
# - Organização de código
# - Análise de dados com dicionários e listas
# - Autonomia na resolução de problemas
#
# ## 📦 Base de Dados
#
# ```python
# vendas_trimestre = {
#     'Ana': [12000, 15000, 13000],
#     'Bruno': [18000, 17500, 16000],
#     'Carlos': [9000, 9500, 10000],
#     'Daniela': [22000, 21000, 23000],
#     'Eduardo': [14000, 13500, 15000]
# }

# %%
vendas_trimestre = {
    'Ana': [12000, 15000, 13000],
    'Bruno': [18000, 17500, 16000],
    'Carlos': [9000, 9500, 10000],
    'Daniela': [22000, 21000, 23000],
    'Eduardo': [14000, 13500, 15000]
}

def linha(tamanho = 68):
    return '-' * tamanho


def cabecalho (msg):
    print(linha(68))
    print(msg.upper().center(68))
    print(linha(68))

def resumo_vendedor(vendedor, total_vendas, media_trimestral, maior, menor):
    cabecalho(vendedor)
    print(f"""Total de vendas: {total_vendas:>51}
Média Mensal de vendas: {media_trimestral:>44.2f}
Maior venda: {maior:>55}
Menor venda: {menor:>55}""")


def resumo_geral(total_geral_vendas, media_geral_venda):
    print(f"""Total Geral de vendas: {total_geral_vendas:>45}
Média Geral de vendas: {media_geral_venda:>45.2f}""")
    

# Programa Principal
cabecalho("ANÁLISE TRIMESTRAL DE VENDAS")

ranking_vendas = []
total_geral_vendas = 0

for vendedor, vendas in vendas_trimestre.items():
    total_vendas_trimestral_vendedor = sum(vendas)
    ranking_vendas.append({'nome_vendedor': vendedor, 'total_vendas': total_vendas_trimestral_vendedor})
    qtd_meses = len(vendas)
    media_trimestral_vendedor = total_vendas_trimestral_vendedor / qtd_meses
    maior_venda = max(vendas)
    menor_venda = min(vendas)
    total_geral_vendas += total_vendas_trimestral_vendedor
    resumo_vendedor(vendedor, total_vendas_trimestral_vendedor, media_trimestral_vendedor, maior_venda, menor_venda)  

for item in ranking_vendas:
    percentual_vendedor_equipe = item['total_vendas'] / total_geral_vendas
    item['Perc_vendas_vendedor'] = percentual_vendedor_equipe

media_geral_vendas = total_geral_vendas / len(ranking_vendas)

cabecalho("RANKING TRIMESTRAL POR VENDEDORES")

ranking_ordenado = sorted(ranking_vendas, key=lambda item: item['total_vendas'], reverse=True)

for posicao, item in enumerate(ranking_ordenado, start=1):
    print(f"{posicao}º lugar: {item['nome_vendedor']:<7} - Qtd. Vendas: {item['total_vendas']} - % Vendedor x Geral: {item['Perc_vendas_vendedor']:.2%}")

cabecalho("INDICADORES GERAIS DA EQUIPE")

resumo_geral(total_geral_vendas, media_geral_vendas)
print(linha())
# Out:
# --------------------------------------------------------------------
#                     ANÁLISE TRIMESTRAL DE VENDAS
# --------------------------------------------------------------------
# --------------------------------------------------------------------
#                                 ANA
# --------------------------------------------------------------------
# Total de vendas:                                               40000
# Média Mensal de vendas:                                     13333.33
# Maior venda:                                                   15000
# Menor venda:                                                   12000
# --------------------------------------------------------------------
#                                BRUNO
# --------------------------------------------------------------------
# Total de vendas:                                               51500
# Média Mensal de vendas:                                     17166.67
# ...
