# %% [markdown]
# Exercício 1: Dashboard de Vendas (Análise de Dados) Você recebeu uma lista com as vendas diárias de uma equipe: vendas = [1500, 2000, 800, 3500, 1200]. Crie um programa que exiba um pequeno relatório contendo:
# 1.	O total de vendas na semana.
# 2.	A média de vendas diária.
# 3.	O valor da melhor venda e da pior venda do período.

# %%
vendas = [1500, 2000, 800, 3500, 1200]

# 1 Total de Vendas
total_vendas = sum(vendas)

# 2 Média de vendas
media_vendas = total_vendas / len(vendas)

# 3 Maior e Menor Venda

maior_venda = max(vendas)
menor_venda = min(vendas)

print(f'''Vendas diárias: {vendas}
Total de vendas: {total_vendas}
Média de vendas: {media_vendas:.0f}
Maior venda: {maior_venda}
Menor venda: {menor_venda}''')
# Out:
# Vendas diárias: [1500, 2000, 800, 3500, 1200]
# Total de vendas: 9000
# Média de vendas: 1800
# Maior venda: 3500
# Menor venda: 800

# %% [markdown]
# Exercício 2: Gestão de Estoque (Edição e Verificação) Uma loja de eletrônicos possui os seguintes produtos: estoque = ["monitor", "teclado", "mouse", "headset"]. O gerente pediu para:
# 1.	Adicionar o item "webcam" ao final da lista.
# 2.	O "teclado" teve seu nome atualizado para "teclado mecanico". Faça essa alteração na lista.
# 3.	Verificar se "impressora" está no estoque. O programa deve exibir True ou False.
# 4.	Remover o "mouse" da lista, pois saiu de linha.

# %%
estoque = ["monitor", "teclado", "mouse", "headset"]
print(estoque)
# Adicionar "webcam"

estoque.append('webcam')
print(estoque)

# Alterar para "teclado mecanico"
estoque[1] = 'teclado mecanico'
print(estoque)


#verificando se 'impressora' faz parte da lista
produto = 'impressora' in estoque
print(produto)

#remover "mouse da lista"
estoque.remove('mouse')
print(estoque)
# Out:
# ['monitor', 'teclado', 'mouse', 'headset']
# ['monitor', 'teclado', 'mouse', 'headset', 'webcam']
# ['monitor', 'teclado mecanico', 'mouse', 'headset', 'webcam']
# False
# ['monitor', 'teclado mecanico', 'headset', 'webcam']

# %% [markdown]
# Exercício 3: Organização de Preços (Ordenação e Slicing) Uma importadora listou os preços de frete em dólar: fretes = [50, 80, 20, 150, 40]. Para apresentar em uma reunião, você deve:
# 1.	Ordenar a lista do maior para o menor preço.
# 2.	Pegar os 2 fretes mais caros (usando fatiamento/slicing) e armazenar em uma nova lista chamada top_fretes.
# 3.	Exibir a lista original ordenada e a lista dos top_fretes.

# %%
fretes = [50, 80, 20, 150, 40]
print(fretes)

#1 
fretes.sort()
print(fretes)

#2
top_fretes = []
maior_frete = max(fretes)
top_fretes.append(maior_frete)
fretes.pop()
maior_frete = max(fretes)
top_fretes.append(maior_frete)
fretes.pop()

top_fretes.sort()
#3
print(fretes)
print(top_fretes)
# Out:
# [50, 80, 20, 150, 40]
# [20, 40, 50, 80, 150]
# [20, 40, 50]
# [80, 150]

# %% [markdown]
# Exercício 4: Sistema de Logística (Busca e Extensão) A empresa "LogTrack" tem uma rota de entregas: rota = ["Sao Paulo", "Campinas", "Jundiai", "Sorocaba"]. Novas cidades foram adicionadas por uma empresa parceira: novas_cidades = ["Itu", "Valinhos"]. Seu script deve:
# 1.	Unir as duas listas em uma só (usando extend).
# 2.	Identificar em qual posição (índice) está a cidade de "Sorocaba".
# 3.	Exibir a lista completa e a posição encontrada.
# 4.	Exibir uma mensagem final: “Sorocaba é a Xª cidade da rota”

# %%
rota = ["Sao Paulo", "Campinas", "Jundiai", "Sorocaba"]
print(rota)
novas_cidades = ["Itu", "Valinhos"]

#1
rota.extend(novas_cidades)
print(rota)

#2
posicao = rota.index('Sorocaba')
print(posicao)

#3
print(f'Rotas: {rota}\nIndice da cidade Sorocaba: {posicao}')

#4
print(f'Sorocaba é a {posicao + 1}ª cidade da rota')
# Out:
# ['Sao Paulo', 'Campinas', 'Jundiai', 'Sorocaba']
# ['Sao Paulo', 'Campinas', 'Jundiai', 'Sorocaba', 'Itu', 'Valinhos']
# 3
# Rotas: ['Sao Paulo', 'Campinas', 'Jundiai', 'Sorocaba', 'Itu', 'Valinhos']
# Indice da cidade Sorocaba: 3
# Sorocaba é a 4ª cidade da rota

# %% [markdown]
# Exercício 5: Atualização de Preços Interativa (Input + Lista) Você tem uma lista de preços de produtos: precos = [100.0, 250.0, 500.0] e uma com o nome: vinhos = ["Branco", "Tinto","Champagne"]. Crie um programa interativo que:
# 1.	Peça para o usuário digitar qual o nome do produto.
# 2.	Peça para o usuário digitar o novo preço.
# 3.	Atualize o preço na lista e exiba as listas completas com os nomes e os preços

# %%
precos = [100.0, 250.0, 500.0]
vinhos = ["Branco", "Tinto", "Champagne"]

#1 
produto = input('Digite o nome do produto: ')

#2
novo_preco = float(input('Digite o novo preço do produto: R$ '))

#3
indice_vinho = vinhos.index(produto)
precos[indice_vinho] = novo_preco

print(vinhos)
print(precos)
# Out:
# ['Branco', 'Tinto', 'Champagne']
# [200.0, 250.0, 500.0]
