# %% [markdown]
# Exercício 1: Cálculo de Bônus de Vendas (RH/Vendas)
# Cenário: Uma empresa decidiu dar um bônus de 10% sobre o faturamento total para a equipe de vendas. Objetivo: Calcule o valor do bônus e o faturamento final da empresa após subtrair esse bônus.
# ●	Faturamento inicial: 50.000
# ●	Percentual de bônus: 0.10

# %%
faturamento_inicial = 50000
percentual_bonus = 0.10
bonus = (faturamento_inicial * percentual_bonus)
faturamento_final = faturamento_inicial - bonus

print(f'''O faturamento inicial: R$ {faturamento_inicial:.2f}
Valor do Bônus: R$ {bonus:.2f}
O faturamento final: R$ {faturamento_final:.2f}''')
# Out:
# O faturamento inicial: R$ 50000.00
# Valor do Bônus: R$ 5000.00
# O faturamento final: R$ 45000.00

# %% [markdown]
# Exercício 2: Controle de Estoque de E-commerce (Logística)
# Cenário: Um e-commerce começou o dia com 250 unidades de um smartphone no estoque. Durante o dia, foram vendidos 78 unidades e chegaram mais 100 unidades de um fornecedor. Objetivo: Atualize a variável de estoque e exiba o saldo final.

# %%
estoque_inicial = 250
vendidos = 78
novos_itens = 100

estoque_final = estoque_inicial - vendidos + novos_itens

print(f'''Estoque Inicial = {estoque_inicial}
Vendidos = {vendidos}
Novos itens = {novos_itens}
Estoque Final = {estoque_final}
''')
# Out:
# Estoque Inicial = 250
# Vendidos = 78
# Novos itens = 100
# Estoque Final = 272

# %% [markdown]
# Exercício 3: Divisão de Cargas (Logística/Transporte)
# Cenário: Uma transportadora precisa levar 1.250 caixas em caminhões pequenos. Cada caminhão suporta exatamente 12 caixas. Objetivo: 1. Quantos caminhões sairão totalmente cheios? (Use //) 2. Quantas caixas sobrarão para serem enviadas em uma última viagem menor? (Use %)

# %%
estoque = 1250
capacidade_caminhao = 12

total_caminhao_cheio = estoque // capacidade_caminhao
carro_fracionado = estoque % capacidade_caminhao

print(f'''Capacidade caminhão: {capacidade_caminhao} caixas
Total de caminhões cheios: {total_caminhao_cheio} caminhões
Caixas sobressalentes: {carro_fracionado} caixas
''')
# Out:
# Capacidade caminhão: 12 caixas
# Total de caminhões cheios: 104 caminhões
# Caixas sobressalentes: 2 caixas

# %% [markdown]
# Exercício 4: Análise de Margem de Lucro (Financeiro)
# Cenário: Uma consultoria faturou R$ 15.000,00 em um projeto. Os custos fixos foram de R$ 5.000,00 e o imposto sobre o faturamento é de 15%. Objetivo: Calcule o imposto, o lucro líquido e a margem de lucro (Lucro / Faturamento). No final, crie uma variável booleana chamada meta_atingida que verifica se a margem de lucro é superior a 0.30 (30%).

# %%
faturamento = 15000
custo = 5000
taxa_imposto = 0.15
imposto = faturamento * taxa_imposto

lucro_liquido = faturamento - custo - imposto
margem_lucro = lucro_liquido / faturamento

meta_atinginda = margem_lucro >= 0.30

print(f'''Faturamento: R$ {faturamento:.2f}
Custo Fixo: R$ {custo:.2f}
Taxa imposto: {taxa_imposto:.2%}
Total de imposto: R$ {imposto:.2f}
Lucro Liquido: R$ {lucro_liquido:.2f}
Margem de Lucro: {margem_lucro:.2%}
Meta: {meta_atinginda}
''')
# Out:
# Faturamento: R$ 15000.00
# Custo Fixo: R$ 5000.00
# Taxa imposto: 15.00%
# Total de imposto: R$ 2250.00
# Lucro Liquido: R$ 7750.00
# Margem de Lucro: 51.67%
# Meta: True

# %% [markdown]
# Exercício 5: Conversão de Tempo de Contrato (Gestão de Projetos)
# Cenário: Um contrato de manutenção de software tem a duração de 40 meses. O cliente quer ver esse tempo no formato: "X anos e Y meses". Objetivo: Utilize os operadores de divisão inteira e resto da divisão para converter os 40 meses.

# %%
duracao = 40

ano = duracao // 12
meses = duracao % 12

print(f'{ano} anos e {meses} meses.')
# Out:
# 3 anos e 4 meses.
