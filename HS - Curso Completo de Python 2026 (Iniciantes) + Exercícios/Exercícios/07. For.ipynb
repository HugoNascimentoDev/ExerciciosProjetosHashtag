# %% [markdown]
# Exercício 1: Automação de Convites (Setor de Eventos/RH) A empresa terá um treinamento e você precisa simular o envio de 10 lembretes no console fazendo a contagem regressiva para aparecer no sistema da empresa. Use a função range() para imprimir 10 vezes a mensagem: "Lembrete: O treinamento de Python começa em X minutos.

# %%
for n in range(10, -1,-1):
    print(f'Lembrete: O trenaimento em Python começa em {n} minutos!')
# Out:
# Lembrete: O trenaimento em Python começa em 10 minutos!
# Lembrete: O trenaimento em Python começa em 9 minutos!
# Lembrete: O trenaimento em Python começa em 8 minutos!
# Lembrete: O trenaimento em Python começa em 7 minutos!
# Lembrete: O trenaimento em Python começa em 6 minutos!
# Lembrete: O trenaimento em Python começa em 5 minutos!
# Lembrete: O trenaimento em Python começa em 4 minutos!
# Lembrete: O trenaimento em Python começa em 3 minutos!
# Lembrete: O trenaimento em Python começa em 2 minutos!
# Lembrete: O trenaimento em Python começa em 1 minutos!
# Lembrete: O trenaimento em Python começa em 0 minutos!

# %% [markdown]
# Exercício 2: Cálculo de Comissão Progressiva (Setor de Vendas) Você tem uma lista de vendas de um vendedor: vendas = [2000, 5000, 1000, 8000, 3000]. A regra de comissão é:
#
# ●	Vendas acima de R$ 4.000,00: comissão de 10%.
#
# ●	Vendas até R$ 4.000,00: comissão de 5%. Crie um programa que percorra a lista e, ao final, exiba o valor total que o vendedor receberá de comissão.

# %%
vendas = [2000, 5000, 1000, 8000, 3000]

comissao = []

for v in vendas:
    if v > 4000:
        p_comissao = 0.10
    else:
        p_comissao = 0.05

    valor_comissao = v * p_comissao
    comissao.append(valor_comissao)
vendedor = 1
for c in comissao:
    print(f'{vendedor}º VENDEDOR -> COMISSÃO R$ {c:.2f}')
    vendedor+=1
# Out:
# 1º VENDEDOR -> COMISSÃO R$ 100.00
# 2º VENDEDOR -> COMISSÃO R$ 500.00
# 3º VENDEDOR -> COMISSÃO R$ 50.00
# 4º VENDEDOR -> COMISSÃO R$ 800.00
# 5º VENDEDOR -> COMISSÃO R$ 150.00

# %% [markdown]
# Exercício 3: Verificação de Estoque Crítico (Setor de Logística) Dada a lista de produtos estoque_produtos = ["monitor", "teclado", "mouse", "headset", "gabinete"] e a lista correspondente de quantidades estoque_quantidades = [5, 12, 2, 8, 15].
#
# O estoque mínimo para qualquer item é 8 unidades.
#
# Crie um programa que percorra as listas e, para cada item que esteja abaixo do mínimo, imprima: "ALERTA: O produto [nome] está com apenas [quantidade] unidades no estoque!".

# %%
estoque_produtos = ["monitor", "teclado", "mouse", "headset", "gabinete"]
estoque_quantidades = [5, 12, 2, 8, 15]

for e in estoque_quantidades:
    i = estoque_quantidades.index(e)
    if e < 8:
        print(f"ALERTA: O produto {estoque_produtos[i].upper()} está com apenas {e} unidades no estoque!")
# Out:
# ALERTA: O produto MONITOR está com apenas 5 unidades no estoque!
# ALERTA: O produto MOUSE está com apenas 2 unidades no estoque!

# %% [markdown]
# Exercício 4: Análise de Custos Mensais (Setor Financeiro) Você tem dois dicionários: um com a meta de gastos de cada mês e outro com os gastos reais. metas = {"jan": 1000, "fev": 1200, "mar": 1100} gastos = {"jan": 900, "fev": 1350, "mar": 1100} Crie um loop que percorra os meses e informe para cada mês:
#
#
# ●	Se o gasto foi menor ou igual à meta: "Mês [mês]: Dentro do orçamento."
#
# ●	Se o gasto ultrapassou a meta: "Mês [mês]: Orçamento estourado em R$[valor da diferença]."

# %%
metas = {"jan": 1000, "fev": 1200, "mar": 1100}

gastos = {"jan": 900, "fev": 1350, "mar": 1100}

for m in metas:
    if gastos[m] > metas[m]:
        print(f'MÊS({m.upper()}): Orçamento estourado em R$ {gastos[m] - metas[m]:.2f}.')
    else:
        print(f'MÊS({m.upper()}): Dentro do orçamento.')
# Out:
# MÊS(JAN): Dentro do orçamento.
# MÊS(FEV): Orçamento estourado em R$ 150.00.
# MÊS(MAR): Dentro do orçamento.

# %% [markdown]
# Exercício 5: Reajuste Geral de Preços (Setor Comercial) Devido à inflação, a empresa decidiu aumentar o preço de todos os seus produtos em um percentual decidido pelo usuário. O catálogo atual é: precos = {"celular": 1500, "tablet": 2500, "notebook": 5000}.
# 1.	Peça ao usuário para digitar o percentual de aumento (ex: 10 para 10%).
# 2.	Use um loop para atualizar cada preço dentro do dicionário.
# 3.	Ao final, exiba o novo catálogo de preços formatado.

# %%
precos = {"celular": 1500, "tablet": 2500, "notebook": 5000}

p_aumento = float(input('Digite o percentual do aumento: % ')) / 100

for p in precos:
    print(f'Preço Antigo - {p.upper()}: R$ {precos[p]:.2f}')
    novo_preco = precos[p] * (1 + p_aumento)
    precos[p] = novo_preco

for produtos, preco in precos.items():
    print(f'Preço Novo - {produtos.upper()}: R$ {preco:.2f}')
# Out:
# Preço Antigo - CELULAR: R$ 1500.00
# Preço Antigo - TABLET: R$ 2500.00
# Preço Antigo - NOTEBOOK: R$ 5000.00
# Preço Novo - CELULAR: R$ 1650.00
# Preço Novo - TABLET: R$ 2750.00
# Preço Novo - NOTEBOOK: R$ 5500.00
